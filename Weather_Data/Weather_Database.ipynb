# %%
import numpy as np
from citipy import citipy  
from config import weather_api_key 
import requests
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 734

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&appid=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval")
print("------------------------")


record_count = 1
set_count = 1

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ", "+")
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
  
    try:
        city_weather = requests.get(city_url).json()
       
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
    
    except:
        print("City not found. Skipping...")
        pass


print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 1 of Set 1 | fier
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | marawi
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | new norfolk
# Processing Record 7 of Set 1 | costa rica
# Processing Record 8 of Set 1 | turka
# Processing Record 9 of Set 1 | bengkulu
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | guerrero negro
# Processing Record 12 of Set 1 | elizabeth city
# Processing Record 13 of Set 1 | bethel
# Processing Record 14 of Set 1 | knysna
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | simao
# Processing Record 17 of Set 1 | severomuysk
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | ardatov
# Processing Record 27 of Set 1 | denpasar
# Processing Record 28 of Set 1 | mar del plata
# Processing Record 29 of Set 1 | san patricio
# Processing Record 30 of Set 1 | chimbote
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | nikolskoye
# Processing Record 33 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 1 | brezno
# Processing Record 35 of Set 1 | cimitarra
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | hithadhoo
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 1 | yuxia
# Processing Record 41 of Set 1 | kaitangata
# Processing Record 42 of Set 1 | saskylakh
# Processing Record 43 of Set 1 | kota kinabalu
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | turukhansk
# Processing Record 49 of Set 1 | port alfred
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | zlin
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | provideniya
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | te anau
# Processing Record 6 of Set 2 | ponta do sol
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | bud
# Processing Record 10 of Set 2 | anadyr
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | sawakin
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | ewo
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | rafaela
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | egvekinot
# Processing Record 22 of Set 2 | caravelas
# Processing Record 23 of Set 2 | caluquembe
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | chuy
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | kangaatsiaq
# Processing Record 28 of Set 2 | yulara
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | kieta
# Processing Record 31 of Set 2 | abonnema
# Processing Record 32 of Set 2 | borogontsy
# Processing Record 33 of Set 2 | severo-kurilsk
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | menongue
# Processing Record 36 of Set 2 | tricase
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | avarua
# Processing Record 39 of Set 2 | fairbanks
# Processing Record 40 of Set 2 | les cayes
# Processing Record 41 of Set 2 | kodiak
# Processing Record 42 of Set 2 | east london
# Processing Record 43 of Set 2 | belmonte
# Processing Record 44 of Set 2 | honiara
# Processing Record 45 of Set 2 | itarema
# Processing Record 46 of Set 2 | mataura
# Processing Record 47 of Set 2 | saint anthony
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | nenjiang
# Processing Record 50 of Set 2 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 3 | hommelvik
# Processing Record 2 of Set 3 | miguel hidalgo
# Processing Record 3 of Set 3 | fort nelson
# Processing Record 4 of Set 3 | pasni
# Processing Record 5 of Set 3 | hare bay
# Processing Record 6 of Set 3 | iqaluit
# Processing Record 7 of Set 3 | chara
# Processing Record 8 of Set 3 | burica
# City not found. Skipping...
# Processing Record 9 of Set 3 | hofn
# Processing Record 10 of Set 3 | talakan
# Processing Record 11 of Set 3 | nokaneng
# Processing Record 12 of Set 3 | aranos
# Processing Record 13 of Set 3 | la ronge
# Processing Record 14 of Set 3 | el alto
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | tilzapotla
# Processing Record 17 of Set 3 | lengshuitan
# Processing Record 18 of Set 3 | hambantota
# Processing Record 19 of Set 3 | grand gaube
# Processing Record 20 of Set 3 | jackson
# Processing Record 21 of Set 3 | treinta y tres
# Processing Record 22 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 3 | tigzirt
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | kahului
# Processing Record 26 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 3 | saint george
# Processing Record 28 of Set 3 | tual
# Processing Record 29 of Set 3 | arkhangelsk
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | silchar
# Processing Record 32 of Set 3 | sembakung
# Processing Record 33 of Set 3 | tasiilaq
# Processing Record 34 of Set 3 | nizwa
# Processing Record 35 of Set 3 | snezhnogorsk
# Processing Record 36 of Set 3 | isangel
# Processing Record 37 of Set 3 | sept-iles
# Processing Record 38 of Set 3 | arraial do cabo
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | marrakesh
# Processing Record 41 of Set 3 | salalah
# Processing Record 42 of Set 3 | ilulissat
# Processing Record 43 of Set 3 | west wendover
# Processing Record 44 of Set 3 | claremorris
# Processing Record 45 of Set 3 | margate
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | vanimo
# Processing Record 48 of Set 3 | madingou
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | srednekolymsk
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | kristiansund
# Processing Record 5 of Set 4 | gujar khan
# Processing Record 6 of Set 4 | eureka
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | champoton
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | ambilobe
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | aras
# Processing Record 13 of Set 4 | tommot
# Processing Record 14 of Set 4 | cabras
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | mahibadhoo
# Processing Record 17 of Set 4 | moron
# Processing Record 18 of Set 4 | malakal
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | albertville
# Processing Record 21 of Set 4 | pochutla
# Processing Record 22 of Set 4 | constitucion
# Processing Record 23 of Set 4 | sao luiz gonzaga
# Processing Record 24 of Set 4 | sechura
# Processing Record 25 of Set 4 | bourne
# Processing Record 26 of Set 4 | yumen
# Processing Record 27 of Set 4 | mount isa
# Processing Record 28 of Set 4 | khasan
# Processing Record 29 of Set 4 | bowen
# Processing Record 30 of Set 4 | myronivka
# Processing Record 31 of Set 4 | nizhnevartovsk
# Processing Record 32 of Set 4 | tungkang
# City not found. Skipping...
# Processing Record 33 of Set 4 | seoul
# Processing Record 34 of Set 4 | batagay-alyta
# Processing Record 35 of Set 4 | kalmunai
# Processing Record 36 of Set 4 | pombas
# Processing Record 37 of Set 4 | hirara
# Processing Record 38 of Set 4 | brae
# Processing Record 39 of Set 4 | la asuncion
# Processing Record 40 of Set 4 | bukama
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | manzhouli
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | ancud
# Processing Record 45 of Set 4 | placido de castro
# Processing Record 46 of Set 4 | atar
# Processing Record 47 of Set 4 | nhulunbuy
# Processing Record 48 of Set 4 | cidreira
# Processing Record 49 of Set 4 | puerto del rosario
# Processing Record 50 of Set 4 | gimli
# Processing Record 1 of Set 5 | quelimane
# Processing Record 2 of Set 5 | paamiut
# Processing Record 3 of Set 5 | abu dhabi
# Processing Record 4 of Set 5 | touros
# Processing Record 5 of Set 5 | nizhniy kuranakh
# Processing Record 6 of Set 5 | mayo
# Processing Record 7 of Set 5 | souillac
# Processing Record 8 of Set 5 | umm kaddadah
# Processing Record 9 of Set 5 | hobyo
# Processing Record 10 of Set 5 | hualmay
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | cairns
# Processing Record 13 of Set 5 | pangnirtung
# Processing Record 14 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 5 | nerchinskiy zavod
# Processing Record 16 of Set 5 | comodoro rivadavia
# Processing Record 17 of Set 5 | wanning
# Processing Record 18 of Set 5 | artemovsk
# Processing Record 19 of Set 5 | male
# Processing Record 20 of Set 5 | tibu
# Processing Record 21 of Set 5 | marzuq
# Processing Record 22 of Set 5 | lorengau
# Processing Record 23 of Set 5 | rudbar
# Processing Record 24 of Set 5 | ulaangom
# Processing Record 25 of Set 5 | ketchikan
# Processing Record 26 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 5 | hami
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | cherskiy
# Processing Record 30 of Set 5 | udon thani
# Processing Record 31 of Set 5 | lebu
# Processing Record 32 of Set 5 | airai
# Processing Record 33 of Set 5 | ulaanbaatar
# Processing Record 34 of Set 5 | hirado
# Processing Record 35 of Set 5 | ostrovnoy
# Processing Record 36 of Set 5 | coahuayana
# Processing Record 37 of Set 5 | nemuro
# Processing Record 38 of Set 5 | broken hill
# Processing Record 39 of Set 5 | saint-augustin
# Processing Record 40 of Set 5 | saryg-sep
# Processing Record 41 of Set 5 | muros
# Processing Record 42 of Set 5 | celestun
# Processing Record 43 of Set 5 | labuhan
# Processing Record 44 of Set 5 | salinopolis
# Processing Record 45 of Set 5 | sobolevo
# Processing Record 46 of Set 5 | samarai
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | namibe
# Processing Record 49 of Set 5 | sola
# Processing Record 50 of Set 5 | zaranj
# Processing Record 1 of Set 6 | alibag
# Processing Record 2 of Set 6 | flin flon
# Processing Record 3 of Set 6 | aklavik
# Processing Record 4 of Set 6 | malpe
# Processing Record 5 of Set 6 | omboue
# Processing Record 6 of Set 6 | trabzon
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | loandjili
# Processing Record 9 of Set 6 | nanortalik
# Processing Record 10 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 11 of Set 6 | foz do iguacu
# Processing Record 12 of Set 6 | warwick
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | tonstad
# Processing Record 15 of Set 6 | black river
# Processing Record 16 of Set 6 | qui nhon
# Processing Record 17 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 6 | fuerte olimpo
# Processing Record 19 of Set 6 | iskateley
# Processing Record 20 of Set 6 | sarny
# Processing Record 21 of Set 6 | sars
# Processing Record 22 of Set 6 | phan thiet
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | lagoa
# Processing Record 25 of Set 6 | kavaratti
# Processing Record 26 of Set 6 | port hedland
# Processing Record 27 of Set 6 | prainha
# Processing Record 28 of Set 6 | goundi
# Processing Record 29 of Set 6 | kavieng
# Processing Record 30 of Set 6 | hadejia
# Processing Record 31 of Set 6 | vinderup
# Processing Record 32 of Set 6 | shingu
# Processing Record 33 of Set 6 | port lincoln
# Processing Record 34 of Set 6 | katobu
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | mjolby
# Processing Record 37 of Set 6 | north bend
# Processing Record 38 of Set 6 | virginia beach
# Processing Record 39 of Set 6 | dongsheng
# Processing Record 40 of Set 6 | gat
# Processing Record 41 of Set 6 | laguna
# Processing Record 42 of Set 6 | gamba
# Processing Record 43 of Set 6 | chiang khong
# Processing Record 44 of Set 6 | plouzane
# Processing Record 45 of Set 6 | porto novo
# Processing Record 46 of Set 6 | gainesville
# Processing Record 47 of Set 6 | durban
# Processing Record 48 of Set 6 | tezu
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | general pico
# Processing Record 1 of Set 7 | hassleholm
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | asau
# Processing Record 5 of Set 7 | varhaug
# Processing Record 6 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 7 | lovozero
# Processing Record 10 of Set 7 | sumenep
# Processing Record 11 of Set 7 | altamira
# Processing Record 12 of Set 7 | kentau
# Processing Record 13 of Set 7 | kjollefjord
# Processing Record 14 of Set 7 | annau
# Processing Record 15 of Set 7 | porto walter
# Processing Record 16 of Set 7 | ji-parana
# City not found. Skipping...
# Processing Record 17 of Set 7 | ginir
# Processing Record 18 of Set 7 | dryden
# Processing Record 19 of Set 7 | lata
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | belyy yar
# Processing Record 22 of Set 7 | phalaborwa
# Processing Record 23 of Set 7 | pachino
# Processing Record 24 of Set 7 | parry sound
# Processing Record 25 of Set 7 | orocue
# Processing Record 26 of Set 7 | sisimiut
# Processing Record 27 of Set 7 | warri
# Processing Record 28 of Set 7 | ixtapa
# Processing Record 29 of Set 7 | teguise
# Processing Record 30 of Set 7 | kaspiyskiy
# Processing Record 31 of Set 7 | toyooka
# Processing Record 32 of Set 7 | dickinson
# Processing Record 33 of Set 7 | sorland
# Processing Record 34 of Set 7 | mahebourg
# Processing Record 35 of Set 7 | beira
# Processing Record 36 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 7 | bambous virieux
# Processing Record 38 of Set 7 | ibra
# Processing Record 39 of Set 7 | lithakia
# Processing Record 40 of Set 7 | hammerfest
# Processing Record 41 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 42 of Set 7 | paraisopolis
# Processing Record 43 of Set 7 | ngama
# Processing Record 44 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 7 | grindavik
# Processing Record 46 of Set 7 | komsomolskiy
# Processing Record 47 of Set 7 | portland
# Processing Record 48 of Set 7 | naftah
# City not found. Skipping...
# Processing Record 49 of Set 7 | mnogovershinnyy
# Processing Record 50 of Set 7 | alofi
# Processing Record 1 of Set 8 | mackay
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | inuvik
# Processing Record 4 of Set 8 | marquelia
# Processing Record 5 of Set 8 | makinsk
# Processing Record 6 of Set 8 | mizdah
# Processing Record 7 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 8 | dunedin
# Processing Record 9 of Set 8 | zeya
# Processing Record 10 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 8 | tianpeng
# Processing Record 12 of Set 8 | rosetta
# Processing Record 13 of Set 8 | alexandria
# Processing Record 14 of Set 8 | langxiang
# Processing Record 15 of Set 8 | boa vista
# Processing Record 16 of Set 8 | faridpur
# Processing Record 17 of Set 8 | luderitz
# Processing Record 18 of Set 8 | pitimbu
# Processing Record 19 of Set 8 | abalak
# Processing Record 20 of Set 8 | koungou
# Processing Record 21 of Set 8 | roald
# Processing Record 22 of Set 8 | kiunga
# Processing Record 23 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 24 of Set 8 | lebork
# Processing Record 25 of Set 8 | svetlogorsk
# Processing Record 26 of Set 8 | buta
# Processing Record 27 of Set 8 | rosarito
# Processing Record 28 of Set 8 | aswan
# Processing Record 29 of Set 8 | eldorado
# Processing Record 30 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 8 | kurilsk
# Processing Record 32 of Set 8 | ust-kulom
# Processing Record 33 of Set 8 | ukiah
# Processing Record 34 of Set 8 | naze
# Processing Record 35 of Set 8 | maniitsoq
# Processing Record 36 of Set 8 | saint-joseph
# Processing Record 37 of Set 8 | san quintin
# Processing Record 38 of Set 8 | leningradskiy
# Processing Record 39 of Set 8 | kisangani
# Processing Record 40 of Set 8 | teahupoo
# Processing Record 41 of Set 8 | itupiranga
# Processing Record 42 of Set 8 | half moon bay
# Processing Record 43 of Set 8 | mubi
# Processing Record 44 of Set 8 | tilichiki
# Processing Record 45 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 8 | narsaq
# Processing Record 47 of Set 8 | nishihara
# Processing Record 48 of Set 8 | concepcion
# Processing Record 49 of Set 8 | mangrol
# Processing Record 50 of Set 8 | chiredzi
# Processing Record 1 of Set 9 | rio cuarto
# Processing Record 2 of Set 9 | collie
# Processing Record 3 of Set 9 | tahe
# Processing Record 4 of Set 9 | chulman
# Processing Record 5 of Set 9 | urengoy
# Processing Record 6 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 9 | zalantun
# Processing Record 8 of Set 9 | meulaboh
# Processing Record 9 of Set 9 | thunder bay
# Processing Record 10 of Set 9 | bodden town
# Processing Record 11 of Set 9 | chapais
# Processing Record 12 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 9 | jacksonville
# Processing Record 14 of Set 9 | coquimbo
# Processing Record 15 of Set 9 | ishim
# Processing Record 16 of Set 9 | bose
# Processing Record 17 of Set 9 | monrovia
# Processing Record 18 of Set 9 | tungor
# Processing Record 19 of Set 9 | kitgum
# Processing Record 20 of Set 9 | araguaina
# Processing Record 21 of Set 9 | sioux lookout
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 9 | biak
# Processing Record 25 of Set 9 | sao joao da barra
# Processing Record 26 of Set 9 | pangai
# Processing Record 27 of Set 9 | westerland
# Processing Record 28 of Set 9 | eyemouth
# Processing Record 29 of Set 9 | rawson
# Processing Record 30 of Set 9 | mehamn
# Processing Record 31 of Set 9 | rosendal
# Processing Record 32 of Set 9 | severo-yeniseyskiy
# Processing Record 33 of Set 9 | beringovskiy
# Processing Record 34 of Set 9 | morondava
# Processing Record 35 of Set 9 | oranjemund
# Processing Record 36 of Set 9 | benguela
# Processing Record 37 of Set 9 | martinho campos
# Processing Record 38 of Set 9 | maceio
# Processing Record 39 of Set 9 | husavik
# Processing Record 40 of Set 9 | port hardy
# Processing Record 41 of Set 9 | najran
# Processing Record 42 of Set 9 | tynset
# Processing Record 43 of Set 9 | moyale
# Processing Record 44 of Set 9 | buala
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | malangwa
# Processing Record 47 of Set 9 | mocuba
# Processing Record 48 of Set 9 | vreed en hoop
# City not found. Skipping...
# Processing Record 49 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 9 | san cristobal
# Processing Record 1 of Set 10 | neuquen
# Processing Record 2 of Set 10 | rabaul
# Processing Record 3 of Set 10 | mwense
# Processing Record 4 of Set 10 | ayagoz
# Processing Record 5 of Set 10 | talcahuano
# Processing Record 6 of Set 10 | ilo
# Processing Record 7 of Set 10 | mogadishu
# Processing Record 8 of Set 10 | ye
# City not found. Skipping...
# Processing Record 9 of Set 10 | lavumisa
# Processing Record 10 of Set 10 | krasnyy gulyay
# Processing Record 11 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 12 of Set 10 | ocampo
# Processing Record 13 of Set 10 | bensonville
# Processing Record 14 of Set 10 | whitianga
# Processing Record 15 of Set 10 | bambanglipuro
# Processing Record 16 of Set 10 | srandakan
# Processing Record 17 of Set 10 | berdigestyakh
# Processing Record 18 of Set 10 | sakakah
# Processing Record 19 of Set 10 | balabac
# Processing Record 20 of Set 10 | santa isabel do rio negro
# Processing Record 21 of Set 10 | zatoka
# Processing Record 22 of Set 10 | padang
# Processing Record 23 of Set 10 | kiruna
# Processing Record 24 of Set 10 | chkalovskoye
# Processing Record 25 of Set 10 | shimoda
# Processing Record 26 of Set 10 | nkhata bay
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | adrar
# Processing Record 29 of Set 10 | ozinki
# Processing Record 30 of Set 10 | namwala
# Processing Record 31 of Set 10 | goderich
# Processing Record 32 of Set 10 | dingle
# Processing Record 33 of Set 10 | bela vista
# Processing Record 34 of Set 10 | kasongo-lunda
# Processing Record 35 of Set 10 | yatou
# Processing Record 36 of Set 10 | duz
# City not found. Skipping...
# Processing Record 37 of Set 10 | basco
# Processing Record 38 of Set 10 | solnechnyy
# Processing Record 39 of Set 10 | gillette
# Processing Record 40 of Set 10 | yangambi
# Processing Record 41 of Set 10 | altay
# Processing Record 42 of Set 10 | namatanai
# Processing Record 43 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 44 of Set 10 | andenes
# Processing Record 45 of Set 10 | gallup
# Processing Record 46 of Set 10 | port-gentil
# Processing Record 47 of Set 10 | gazanjyk
# Processing Record 48 of Set 10 | warrington
# Processing Record 49 of Set 10 | sitka
# Processing Record 50 of Set 10 | palauig
# Processing Record 1 of Set 11 | ninghai
# Processing Record 2 of Set 11 | flinders
# Processing Record 3 of Set 11 | novopokrovka
# Processing Record 4 of Set 11 | huarmey
# Processing Record 5 of Set 11 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 6 of Set 11 | haapiti
# Processing Record 7 of Set 11 | oyama
# Processing Record 8 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 11 | turinskaya sloboda
# Processing Record 10 of Set 11 | juye
# Processing Record 11 of Set 11 | belgaum
# Processing Record 12 of Set 11 | chengde
# Processing Record 13 of Set 11 | hamilton
# Processing Record 14 of Set 11 | college
# Processing Record 15 of Set 11 | atbasar
# Processing Record 16 of Set 11 | sovetskiy
# Processing Record 17 of Set 11 | jiuquan
# Processing Record 18 of Set 11 | garden city
# Processing Record 19 of Set 11 | port blair
# Processing Record 20 of Set 11 | lompoc
# Processing Record 21 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 11 | sayan
# Processing Record 23 of Set 11 | finnsnes
# Processing Record 24 of Set 11 | marsh harbour
# Processing Record 25 of Set 11 | ust-kan
# Processing Record 26 of Set 11 | talalayivka
# Processing Record 27 of Set 11 | pemba
# Processing Record 28 of Set 11 | obuasi
# Processing Record 29 of Set 11 | castro
# Processing Record 30 of Set 11 | anloga
# Processing Record 31 of Set 11 | jarjis
# City not found. Skipping...
# Processing Record 32 of Set 11 | krasnoshchekovo
# Processing Record 33 of Set 11 | endicott
# Processing Record 34 of Set 11 | macenta
# Processing Record 35 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 11 | birao
# Processing Record 37 of Set 11 | bikaner
# Processing Record 38 of Set 11 | rundu
# Processing Record 39 of Set 11 | vikhorevka
# Processing Record 40 of Set 11 | alpine
# Processing Record 41 of Set 11 | nichinan
# Processing Record 42 of Set 11 | iquique
# Processing Record 43 of Set 11 | mineiros
# Processing Record 44 of Set 11 | roseland
# Processing Record 45 of Set 11 | salto
# Processing Record 46 of Set 11 | verkhniye kigi
# Processing Record 47 of Set 11 | tiznit
# Processing Record 48 of Set 11 | yerbogachen
# Processing Record 49 of Set 11 | mozarlandia
# Processing Record 50 of Set 11 | olafsvik
# Processing Record 1 of Set 12 | eatonton
# Processing Record 2 of Set 12 | henties bay
# Processing Record 3 of Set 12 | tuatapere
# Processing Record 4 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 5 of Set 12 | shonguy
# Processing Record 6 of Set 12 | kalaleh
# Processing Record 7 of Set 12 | maningrida
# Processing Record 8 of Set 12 | azare
# Processing Record 9 of Set 12 | carutapera
# Processing Record 10 of Set 12 | clyde river
# Processing Record 11 of Set 12 | kampene
# Processing Record 12 of Set 12 | lavrentiya
# Processing Record 13 of Set 12 | santa fe
# Processing Record 14 of Set 12 | antofagasta
# Processing Record 15 of Set 12 | okakarara
# Processing Record 16 of Set 12 | mitu
# Processing Record 17 of Set 12 | salta
# Processing Record 18 of Set 12 | tuzha
# Processing Record 19 of Set 12 | la rioja
# Processing Record 20 of Set 12 | klaksvik
# Processing Record 21 of Set 12 | northam
# Processing Record 22 of Set 12 | bintulu
# Processing Record 23 of Set 12 | arman
# Processing Record 24 of Set 12 | krasnoselkup
# Processing Record 25 of Set 12 | bocaranga
# City not found. Skipping...
# Processing Record 26 of Set 12 | fukue
# Processing Record 27 of Set 12 | falam
# Processing Record 28 of Set 12 | lovington
# Processing Record 29 of Set 12 | lewiston
# Processing Record 30 of Set 12 | ciudad bolivar
# Processing Record 31 of Set 12 | tomatlan
# Processing Record 32 of Set 12 | praia da vitoria
# Processing Record 33 of Set 12 | iquitos
# Processing Record 34 of Set 12 | madison
# Processing Record 35 of Set 12 | kaeo
# Processing Record 36 of Set 12 | sanford
# Processing Record 37 of Set 12 | fuyang
# Processing Record 38 of Set 12 | kraskino
# Processing Record 39 of Set 12 | cururupu
# Processing Record 40 of Set 12 | hlohovec
# Processing Record 41 of Set 12 | san jose
# Processing Record 42 of Set 12 | santa maria
# Processing Record 43 of Set 12 | aviles
# Processing Record 44 of Set 12 | ilebo
# Processing Record 45 of Set 12 | nizhniy ingash
# Processing Record 46 of Set 12 | changji
# Processing Record 47 of Set 12 | pingdingshan
# Processing Record 48 of Set 12 | malatya
# Processing Record 49 of Set 12 | jiangyou
# Processing Record 50 of Set 12 | along
# Processing Record 1 of Set 13 | cody
# Processing Record 2 of Set 13 | megion
# Processing Record 3 of Set 13 | hervey bay
# Processing Record 4 of Set 13 | gasa
# Processing Record 5 of Set 13 | santa cruz del norte
# Processing Record 6 of Set 13 | north battleford
# Processing Record 7 of Set 13 | kudahuvadhoo
# Processing Record 8 of Set 13 | aguimes
# Processing Record 9 of Set 13 | peniche
# Processing Record 10 of Set 13 | illela
# Processing Record 11 of Set 13 | nakhodka
# Processing Record 12 of Set 13 | nueva guinea
# Processing Record 13 of Set 13 | balkanabat
# Processing Record 14 of Set 13 | ca mau
# Processing Record 15 of Set 13 | pacifica
# Processing Record 16 of Set 13 | grand forks
# Processing Record 17 of Set 13 | pali
# Processing Record 18 of Set 13 | tarko-sale
# Processing Record 19 of Set 13 | patharia
# Processing Record 20 of Set 13 | ancona
# Processing Record 21 of Set 13 | ust-nera
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | korla
# Processing Record 24 of Set 13 | moree
# Processing Record 25 of Set 13 | joshimath
# Processing Record 26 of Set 13 | aloleng
# Processing Record 27 of Set 13 | martapura
# Processing Record 28 of Set 13 | koumac
# Processing Record 29 of Set 13 | lena
# Processing Record 30 of Set 13 | bulgan
# Processing Record 31 of Set 13 | ugoofaaru
# Processing Record 32 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 33 of Set 13 | cabedelo
# Processing Record 34 of Set 13 | dobre miasto
# Processing Record 35 of Set 13 | niquero
# Processing Record 36 of Set 13 | mopti
# Processing Record 37 of Set 13 | umm lajj
# Processing Record 38 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 39 of Set 13 | tarakan
# Processing Record 40 of Set 13 | podporozhye
# Processing Record 41 of Set 13 | bongandanga
# Processing Record 42 of Set 13 | nelson bay
# Processing Record 43 of Set 13 | chizhou
# Processing Record 44 of Set 13 | mizan teferi
# Processing Record 45 of Set 13 | katherine
# Processing Record 46 of Set 13 | merauke
# Processing Record 47 of Set 13 | sukumo
# Processing Record 48 of Set 13 | tamandare
# Processing Record 49 of Set 13 | bokajan
# Processing Record 50 of Set 13 | alyangula
# Processing Record 1 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 14 | salamiyah
# Processing Record 3 of Set 14 | karakol
# Processing Record 4 of Set 14 | kapit
# Processing Record 5 of Set 14 | methoni
# Processing Record 6 of Set 14 | curillo
# Processing Record 7 of Set 14 | chaoyang
# Processing Record 8 of Set 14 | kati
# Processing Record 9 of Set 14 | hanstholm
# Processing Record 10 of Set 14 | zhaotong
# Processing Record 11 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 14 | byron bay
# Processing Record 13 of Set 14 | kalabo
# Processing Record 14 of Set 14 | piacabucu
# Processing Record 15 of Set 14 | diffa
# Processing Record 16 of Set 14 | chivay
# Processing Record 17 of Set 14 | iwaki
# Processing Record 18 of Set 14 | matara
# Processing Record 19 of Set 14 | san rafael
# Processing Record 20 of Set 14 | tortoli
# Processing Record 21 of Set 14 | zwedru
# Processing Record 22 of Set 14 | veraval
# Processing Record 23 of Set 14 | makakilo city
# Processing Record 24 of Set 14 | bilma
# Processing Record 25 of Set 14 | kindersley
# Processing Record 26 of Set 14 | houma
# Processing Record 27 of Set 14 | hondo
# Processing Record 28 of Set 14 | abeche
# Processing Record 29 of Set 14 | crossville
# Processing Record 30 of Set 14 | tessalit
# Processing Record 31 of Set 14 | isla vista
# Processing Record 32 of Set 14 | hailun
# Processing Record 33 of Set 14 | noumea
# Processing Record 34 of Set 14 | marabba
# Processing Record 35 of Set 14 | macaboboni
# City not found. Skipping...
# Processing Record 36 of Set 14 | joao pinheiro
# Processing Record 37 of Set 14 | kvareli
# Processing Record 38 of Set 14 | cockburn town
# Processing Record 39 of Set 14 | oriximina
# Processing Record 40 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 14 | lawrenceburg
# Processing Record 42 of Set 14 | dolinsk
# Processing Record 43 of Set 14 | belousovka
# Processing Record 44 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 45 of Set 14 | haines junction
# Processing Record 46 of Set 14 | riyadh
# Processing Record 47 of Set 14 | zhoucheng
# Processing Record 48 of Set 14 | axim
# Processing Record 49 of Set 14 | tigil
# Processing Record 50 of Set 14 | zharkovskiy
# Processing Record 1 of Set 15 | wajima
# Processing Record 2 of Set 15 | smestad
# Processing Record 3 of Set 15 | visby
# Processing Record 4 of Set 15 | zhangye
# Processing Record 5 of Set 15 | banjar
# Processing Record 6 of Set 15 | tawnat
# City not found. Skipping...
# Processing Record 7 of Set 15 | prince rupert
# Processing Record 8 of Set 15 | disna
# Processing Record 9 of Set 15 | ankpa
# Processing Record 10 of Set 15 | san carlos de bariloche
# Processing Record 11 of Set 15 | uruzgan
# Processing Record 12 of Set 15 | estelle
# Processing Record 13 of Set 15 | tabas
# Processing Record 14 of Set 15 | joura
# Processing Record 15 of Set 15 | ust-kut
# Processing Record 16 of Set 15 | hamada
# Processing Record 17 of Set 15 | baoying
# Processing Record 18 of Set 15 | matamoros
# Processing Record 19 of Set 15 | zeerust
# Processing Record 20 of Set 15 | acari
# Processing Record 21 of Set 15 | westport
# Processing Record 22 of Set 15 | bac lieu
# Processing Record 23 of Set 15 | las palmas
# Processing Record 24 of Set 15 | gizo
# Processing Record 25 of Set 15 | bonavista
# Processing Record 26 of Set 15 | shizukuishi
# Processing Record 27 of Set 15 | luau
# Processing Record 28 of Set 15 | san francisco
# Processing Record 29 of Set 15 | puerto escondido
# Processing Record 30 of Set 15 | praia
# Processing Record 31 of Set 15 | banepa
# Processing Record 32 of Set 15 | san luis
# Processing Record 33 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 34 of Set 15 | paita
# -----------------------
# Data Retrieval Complete
# -----------------------

# %%
city_data_df = pd.DataFrame(city_data)
column_order = ["City", "Country", "Lat", "Lng", "Max Temp",
                "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Fier      AL  40.7239   19.5561     55.56        94         100
# 1      Butaritari      KI   3.0707  172.7902     81.57        81         100
# 2          Marawi      PH   7.9986  124.2928     79.00        89         100
# 3        Saldanha      ZA -33.0117   17.9442     69.80        60           0
# 4  Ribeira Grande      PT  38.5167  -28.7000     63.23        86         100
# 5     New Norfolk      AU -42.7826  147.0587     93.00        16         100
# 6      Costa Rica      BR -23.4167  -54.6500     71.71        86          92
# 7           Turka      UA  49.1541   23.0297     30.00        76         100
# 8        Bengkulu      ID  -3.8004  102.2655     85.28        67         100
# 9       Busselton      AU -33.6500  115.3333     82.99        35           0
#
#    Wind Speed   Current Description
# 0        8.14  heavy intensity rain
# 1       18.19            light rain
# 2        8.01       overcast clouds
# 3        8.05             clear sky
# 4        5.93       overcast clouds
# 5        4.00       overcast clouds
# 6        3.31       overcast clouds
# 7        3.76       overcast clouds
# 8        8.46       overcast clouds
# 9        5.01             clear sky

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
